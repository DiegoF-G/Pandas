# %% [markdown]
# <a href="https://colab.research.google.com/github/diegoflxgarcia/Pandas/blob/main/projeto_imobiliaria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Começando no Pandas 🐼 (Panel Data)...
# - [Documentação do Pandas](https://pandas.pydata.org/docs/index.html)
# - [Artigo da Alura sobre o Pandas](https://www.alura.com.br/artigos/pandas-o-que-e-para-que-serve-como-instalar)
#
# **Observação importante: Execute todas as células em sequência! Pois as que estão abaixo interferem nas já executadas acimas se essas forem executadas novamente. Para isso use o "Executar tudo" no "Ambiente de execução".**

# %%
import pandas as pd

# %%
# Versão a ser utilizada do Pandas
# pip install pandas==1.5.3

# %% [markdown]
# # Conhecendo a base de dados

# %% [markdown]
# ## Importando os dados

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
dados = pd.read_csv(url, sep=';') # base de dados csv convertida em um Dataframe pandas
display(dados)
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
dados.head(10) # 10 primeiros
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# ...

# %%
dados.tail(10) # 10 últimos
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 32950              Apartamento                Tijuca        1      0       0
# 32951              Apartamento        Vila Valqueire        2      0       0
# 32952       Casa de Condomínio       Barra da Tijuca        5      3       4
# 32953              Apartamento                 Méier        2      0       0
# 32954              Box/Garagem                Centro        0      0       0
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area    Valor  Condominio    IPTU
# 32950    28   1000.0       360.0    25.0
# ...

# %%
print(type(dados))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Características gerais da base de dados

# %%
print(dados.shape)
# Out:
# (32960, 9)

# %%
print(dados.columns)
# Out:
# Index(['Tipo', 'Bairro', 'Quartos', 'Vagas', 'Suites', 'Area', 'Valor',
#        'Condominio', 'IPTU'],
#       dtype='object')

# %%
# Método dos objetos dataframe que descreve os tipos dos dados por coluna do dataframe além de outras informações das mesmas
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
# Dados com Dtype object são do tipo string também, e nesse caso obtemos uma Serie pandas do dataframe "dados"
print(dados['Tipo'])
print()
print(type(dados['Tipo']))
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: object
#
# <class 'pandas.core.series.Series'>

# %%
print(dados[['Quartos', 'Valor']])
# Out:
#        Quartos   Valor
# 0            1  1700.0
# 1            2  7000.0
# 2            0  5200.0
# 3            1   800.0
# 4            1   800.0
# ...        ...     ...
# 32955        0   800.0
# 32956        3  1800.0
# 32957        2  1400.0
# 32958        2  3000.0
# 32959        0  6500.0
#
# [32960 rows x 2 columns]

# %% [markdown]
# # Análise exploratória de dados

# %% [markdown]
# ## Qual o valor médio de aluguel por tipo de imóvel?

# %%
display(dados.head(8))
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# 3    800.0       390.0    20.0
# 4    800.0       230.0     NaN
# 5   1200.0         NaN     NaN
# 6   1300.0       301.0    17.0
# 7  22000.0         NaN     NaN

# %%
# Valor médio de todos imóveis
print(dados['Valor'].mean())
# Out:
# 12952.659715265761

# %%
# Agrupando os dados de acordo com a coluna 'Tipo' e calculando a média deles
display(dados.groupby('Tipo').mean(numeric_only=True))
# Out:
#                                Quartos      Vagas     Suites          Area  \
# Tipo
# Apartamento                   2.481569   1.232388   0.875998    119.790498
# Box/Garagem                   0.060976   1.304878   0.000000     17.524390
# Casa                          3.133402   1.795243   1.258532    250.578077
# Casa Comercial                1.562264   2.203774   0.260377    372.241509
# Casa de Condomínio            4.007028   3.101406   2.864458    456.161647
# Casa de Vila                  1.927711   0.389558   0.228916     78.469880
# Chácara                       3.000000   0.000000   0.000000      0.000000
# Conjunto Comercial/Sala       0.040939   2.516801   0.010858    214.472487
# Flat                          1.415966   0.962185   0.754202     65.483193
# Galpão/Depósito/Armazém       0.043339   5.587480   0.000000   2514.810594
# Hotel                        25.500000   2.500000  12.000000    885.500000
# ...

# %%
# Selecionando apenas os alugueis (coluna 'Valor') e calculando a média dos mesmos por tipo
# Repare que obtemos uma serie do dataframe (DataframeGroupby no caso)

media_alugueis = dados.groupby('Tipo')['Valor'].mean()
display(media_alugueis)
# Out:
# Tipo
# Apartamento                      4744.614648
# Box/Garagem                      1899.756098
# Casa                             6793.454922
# Casa Comercial                  14478.264151
# Casa de Condomínio              11952.061245
# Casa de Vila                     1574.369478
# Chácara                          4900.000000
# Conjunto Comercial/Sala         14715.045521
# Flat                             4546.189076
# Galpão/Depósito/Armazém         53407.062600
# Hotel                           25000.000000
# Indústria                      120000.000000
# Loft                             2557.882353
# Loja Shopping/ Ct Comercial      8126.178862
# Loja/Salão                      13769.646770
# Loteamento/Condomínio           22000.000000
# Pousada/Chalé                    1480.000000
# Prédio Inteiro                 498637.239203
# Quitinete                        1246.840909
# Studio                           2400.000000
# Sítio                           12499.000000
# ...

# %%
# Melhorando a visualização transformando em um dataframe e ordenando de forma crescente
"""Nesse caso, para obter um dataframe, basta passar a lista ['Valor'] em vez da string 'Valor'.
   Pois o método groupby entende que você deseja passar várias colunas e assim te devolve um dataframe
   mesmo que seja apenas uma coluna nessa lista"""

display(dados.groupby('Tipo')[['Valor']].mean().sort_values('Valor'))
# Out:
#                                      Valor
# Tipo
# Quitinete                      1246.840909
# Pousada/Chalé                  1480.000000
# Casa de Vila                   1574.369478
# Box/Garagem                    1899.756098
# Studio                         2400.000000
# Loft                           2557.882353
# Flat                           4546.189076
# Apartamento                    4744.614648
# Chácara                        4900.000000
# Casa                           6793.454922
# Loja Shopping/ Ct Comercial    8126.178862
# Casa de Condomínio            11952.061245
# Sítio                         12499.000000
# Loja/Salão                    13769.646770
# Casa Comercial                14478.264151
# Conjunto Comercial/Sala       14715.045521
# Loteamento/Condomínio         22000.000000
# Hotel                         25000.000000
# Terreno Padrão                32567.714286
# Galpão/Depósito/Armazém       53407.062600
# Indústria                    120000.000000
# ...

# %%
# Plotando gráfico...
media_alugueis = dados.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
media_alugueis.plot(kind='barh', figsize=(14, 10), color='purple', xlabel='Valor médio')
# Out:
# <Axes: xlabel='Valor médio', ylabel='Tipo'>

# %% [markdown]
# ## Removendo os imóveis comerciais

# %%
# Todos os tipos
display(dados.Tipo.unique())
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
# Dentro dos tipos esses são considerados comerciais por nós
imoveis_comerciais = ('Conjunto Comercial/Sala',
                      'Prédio Inteiro', 'Loja/Salão',
                      'Galpão/Depósito/Armazém',
                      'Casa Comercial', 'Terreno Padrão',
                      'Loja Shopping/ Ct Comercial',
                      'Box/Garagem', 'Chácara',
                      'Loteamento/Condomínio', 'Sítio',
                      'Pousada/Chalé', 'Hotel', 'Indústria')

# %%
# Consultando apenas os imóveis comerciais
display(dados.query('@imoveis_comerciais in Tipo'))
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 9      Conjunto Comercial/Sala           Centro        0      3       0   695
# 16              Prédio Inteiro         Botafogo        0      0       0   536
# 26     Conjunto Comercial/Sala    São Cristóvão        0      1       0    25
# 29                  Loja/Salão     Campo Grande        0      1       0    35
# ...                        ...              ...      ...    ...     ...   ...
# 32942  Conjunto Comercial/Sala  Barra da Tijuca        0      1       0    55
# 32946  Conjunto Comercial/Sala           Centro        0      0       0   140
# 32948  Conjunto Comercial/Sala           Centro        0      0       0    32
# 32954              Box/Garagem           Centro        0      0       0   755
# 32959  Conjunto Comercial/Sala           Centro        0      0       0   250
#
# ...

# %%
# Agora removendo os imóveis comerciais na consulta
display(dados.query('@imoveis_comerciais not in Tipo'))
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
# Salvando os imóveis residenciais
df = dados.query('@imoveis_comerciais not in Tipo')

df.head() # Tinha um conjunto comercial no índice 2, não tem mais!
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 3  Apartamento           Centro        1      0       0    15   800.0
# 4  Apartamento     Higienópolis        1      0       0    48   800.0
# 5  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 3       390.0  20.0
# 4       230.0   NaN
# 5         NaN   NaN

# %%
# Conferindo mais uma vez...
display(df.Tipo.unique())
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
# Plotando novamente um gráfico, apenas com os imóveis residenciais
df_preco_tipo = df.groupby('Tipo').mean()[['Valor']].sort_values('Valor')

df_preco_tipo.plot(kind='barh', figsize=(14, 10), color ='purple', xlabel='Valor médio')
# Out:
# <ipython-input-337-7276cdfdac3a>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_preco_tipo = df.groupby('Tipo').mean()[['Valor']].sort_values('Valor')
# <Axes: xlabel='Valor médio', ylabel='Tipo'>

# %% [markdown]
# ## Qual o porcentual de cada tipo de imóvel na nossa base de dados?

# %%
# Contando o quanto temos de cada tipo de imóvel (frequência absoluta de cada)
display(df.Tipo.value_counts())
# Out:
# Apartamento           19532
# Casa de Condomínio      996
# Casa                    967
# Quitinete               836
# Flat                    476
# Casa de Vila            249
# Loft                     51
# Studio                    4
# Name: Tipo, dtype: int64

# %%
# Normalizando (frequência relativa de cada), convertendo em um dataframe e ordenando
display(df.Tipo.value_counts(normalize=True).to_frame().sort_values('Tipo'))
# Out:
#                         Tipo
# Studio              0.000173
# Loft                0.002207
# Casa de Vila        0.010774
# Flat                0.020596
# Quitinete           0.036173
# Casa                0.041842
# Casa de Condomínio  0.043096
# Apartamento         0.845139

# %%
# Renomeando a coluna Tipo no dataframe anterior para melhorar a visualização
df_tipo = df.Tipo.value_counts(normalize=True).to_frame().sort_values('Tipo')
df_tipo.rename(columns={'Tipo': 'Porcentagens'}, inplace=True)
display(df_tipo)
# Out:
#                     Porcentagens
# Studio                  0.000173
# Loft                    0.002207
# Casa de Vila            0.010774
# Flat                    0.020596
# Quitinete               0.036173
# Casa                    0.041842
# Casa de Condomínio      0.043096
# Apartamento             0.845139

# %%
# Salvando e plotando...
df_normalizado_tipo = df.Tipo.value_counts(normalize=True).to_frame().sort_values('Tipo')

df_normalizado_tipo.plot(kind='bar', figsize=(14,10), color='green', xlabel='Tipos', ylabel='Porcentual')
# Out:
# <Axes: xlabel='Tipos', ylabel='Porcentual'>

# %% [markdown]
# ### **Selecionando apenas os imóveis do tipo apartamento**

# %%
"""Como os imóveis do tipo apartamento representam mais de 80% de todos os tipos,
   vamos selecionar apenas eles e salvar na mesma variável dos imóveis residenciais, df"""

display(df.query('Tipo=="Apartamento"'))
df = df.query('Tipo=="Apartamento"')
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# 6      Apartamento              Cachambi        2      0       0    50
# 10     Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 32951  Apartamento        Vila Valqueire        2      0       0    52
# 32953  Apartamento                 Méier        2      0       0    70
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 3       800.0       390.0  20.0
# 4       800.0       230.0   NaN
# ...

# %%
display(df.head(8))
# Out:
#            Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento               Centro        1      0       0    15   800.0
# 4   Apartamento         Higienópolis        1      0       0    48   800.0
# 5   Apartamento         Vista Alegre        3      1       0    70  1200.0
# 6   Apartamento             Cachambi        2      0       0    50  1300.0
# 10  Apartamento               Centro        1      0       0    36  1200.0
# 11  Apartamento               Grajaú        2      1       0    70  1500.0
# 12  Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
# 13  Apartamento           Copacabana        1      0       1    40  2000.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   NaN
# 5          NaN   NaN
# 6        301.0  17.0
# 10         NaN   NaN
# 11       642.0  74.0
# 12       455.0  14.0
# 13       561.0  50.0

# %% [markdown]
# # Tratando e filtrando os dados

# %% [markdown]
# ## Lidando com dados nulos

# %% [markdown]
# ## Removendo registros

# %% [markdown]
# ## Filtros

# %% [markdown]
# ### **1. Apartamentos que possuem `1 quarto` e `aluguel menor que 1200`**

# %% [markdown]
# ### **2. `Apartamentos` que possuem pelo menos `2 quartos`, `aluguel menor que 3000` e `area maior que 70`**

# %% [markdown]
# ## Salvando os dados

# %% [markdown]
# # Manipulando os dados

# %% [markdown]
# ## Criando colunas numéricas

# %% [markdown]
# ## Criando colunas categóricas
